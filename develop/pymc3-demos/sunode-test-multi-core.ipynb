# %% [markdown]
# https://github.com/pymc-devs/pymc/issues/4273
# https://github.com/pymc-devs/pymc/issues/3844

# %%
import numpy as np
import sympy
import sunode
import sunode.wrappers.as_theano
import pymc3 as pm

times = np.arange(1900,1921,1)
lynx_data = np.array([
    4.0, 6.1, 9.8, 35.2, 59.4, 41.7, 19.0, 13.0, 8.3, 9.1, 7.4,
    8.0, 12.3, 19.5, 45.7, 51.1, 29.7, 15.8, 9.7, 10.1, 8.6
])
hare_data = np.array([
    30.0, 47.2, 70.2, 77.4, 36.3, 20.6, 18.1, 21.4, 22.0, 25.4,
    27.1, 40.3, 57.0, 76.6, 52.3, 19.5, 11.2, 7.6, 14.6, 16.2, 24.7
])
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
#global lotka_volterra
#global SympyProblem
global step_method
def lotka_volterra(t, y, p):
    """Right hand side of Lotka-Volterra equation.
    All inputs are dataclasses of sympy variables, or in the case
    of non-scalar variables numpy arrays of sympy variables.
    """
    return {
        'hares': p.alpha * y.hares - p.beta * y.lynx * y.hares,
        'lynx': p.delta * y.hares * y.lynx - p.gamma * y.lynx,
    }


with pm.Model() as model:
    hares_start = pm.HalfNormal('hares_start', sd=50)
    lynx_start = pm.HalfNormal('lynx_start', sd=50)
    ratio = pm.Beta('ratio', alpha=0.5, beta=0.5)
    fixed_hares = pm.HalfNormal('fixed_hares', sd=50)
    fixed_lynx = pm.Deterministic('fixed_lynx', ratio * fixed_hares)
    period = pm.Gamma('period', mu=10, sd=1)
    freq = pm.Deterministic('freq', 2 * np.pi / period)
    log_speed_ratio = pm.Normal('log_speed_ratio', mu=0, sd=0.1)
    speed_ratio = np.exp(log_speed_ratio)
    # Compute the parameters of the ode based on our prior parameters
    alpha = pm.Deterministic('alpha', freq * speed_ratio * ratio)
    beta = pm.Deterministic('beta', freq * speed_ratio / fixed_hares)
    gamma = pm.Deterministic('gamma', freq / speed_ratio / ratio)
    delta = pm.Deterministic('delta', freq / speed_ratio / fixed_hares / ratio)
    y_hat, _, problem, solver, _, _ = sunode.wrappers.as_theano.solve_ivp(
        y0={
	    # The initial conditions of the ode. Each variable
	    # needs to specify a theano or numpy variable and a shape.
	    # This dict can be nested.
            'hares': (hares_start, ()),
            'lynx': (lynx_start, ()),
        },
        params={
	    # Each parameter of the ode. sunode will only compute derivatives
	    # with respect to theano variables. The shape needs to be specified
	    # as well. It it infered automatically for numpy variables.
	    # This dict can be nested.
            'alpha': (alpha, ()),
            'beta': (beta, ()),
            'gamma': (gamma, ()),
            'delta': (delta, ()),
            'extra': np.zeros(1),
        },
	# A functions that computes the right-hand-side of the ode using
	# sympy variables.
        rhs=lotka_volterra,
	# The time points where we want to access the solution
        tvals=times,
        t0=times[0],
    )
    # We can access the individual variables of the solution using the
    # variable names.
    pm.Deterministic('hares_mu', y_hat['hares'])
    pm.Deterministic('lynx_mu', y_hat['lynx'])
    sd = pm.HalfNormal('sd')
    pm.Lognormal('hares', mu=y_hat['hares'], sd=sd, observed=hare_data)
    pm.Lognormal('lynx', mu=y_hat['lynx'], sd=sd, observed=lynx_data)

# %% [markdown]
# Even when downgrading Py to < 3.8, the same errors keep appearing. My unique options left are:
# 1. Emulate a Linux OS & Python
# 2. Give in at once and see what happpend using Ray, or not paralleliginz at all

# %%
with model:
    trace = pm.sample(tune=1000, draws=1000, chains=4, cores=4)
# Out:
# /tmp/ipykernel_17206/2177192547.py:2: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(tune=1000, draws=1000, chains=4, cores=4)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sd, log_speed_ratio, period, fixed_hares, ratio, lynx_start, hares_start]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 02:32<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES ERROR]  CVode
#   The right-hand side routine failed at the first call.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 2.98291e-22 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 2.98291e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 2.98291e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 2.98291e-22 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 2.98291e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 2.98291e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.31735e-27 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 5.62274e-34 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900 and h = 2.1449e-39, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 5.62274e-34 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900 and h = 2.1449e-39, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900 and h = 1.95452e-09, the error test failed repeatedly or with |h| = hmin.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 9.81135e-20 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900 and h = 1.95452e-09, the error test failed repeatedly or with |h| = hmin.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 1.51774e-21 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900 and h = 1.51774e-27, the error test failed repeatedly or with |h| = hmin.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 1.51774e-21 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900 and h = 1.51774e-27, the error test failed repeatedly or with |h| = hmin.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.93, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.93, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.96, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.96, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.56, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.56, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.58, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.58, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.78, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.78, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.57, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.57, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.6, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.6, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.33, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.33, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.49, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.49, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.71, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.71, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.46, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.46, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.55, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.55, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.32, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.32, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.33, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.33, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.38, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.38, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.97, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.97, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1901, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1901, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.87, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.87, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.79, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.79, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.74, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.74, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.63, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.63, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.62, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.62, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.41, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.41, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.67, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.67, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.77, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.77, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.35, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.35, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1906.03, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1908.02, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1907.02, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1906.16, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1909.02, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1906.15, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1908.04, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1907.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1906.03, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1905.05, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1909.13, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1908.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1906.07, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1905.2, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1904.19, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1907, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1910.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1910.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1910.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1910.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1910.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1910.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1910.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1910.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1910.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1910.44, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1906.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.78, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.78, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.95, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.95, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.88, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.88, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.76, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.76, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.72, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.72, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.59, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.59, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.76, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.76, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.51, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.51, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.02, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.64, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.64, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.03, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.64, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.64, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.04, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.53, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.53, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.04, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.43, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.85, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.43, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.85, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.04, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.92, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.46, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.92, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.46, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.04, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.73, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.4, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.73, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.4, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.56, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.04, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.56, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.39, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.39, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.46, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.03, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.46, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.44, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.55, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.55, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.03, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.42, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.42, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.05, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.32, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.32, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.03, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.41, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.41, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.03, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.34, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.47, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.34, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.47, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#   At t = 1900.02, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.49, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.38, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.49, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.38, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.02, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.34, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.41, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.34, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.41, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.31, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.31, mxstep steps taken before reaching tout.
#
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.37, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.37, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.3, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.3, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.48, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.48, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.26, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.26, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.28, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.28, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.32, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.32, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.29, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.25, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.29, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.25, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.11, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.16, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.31, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.16, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.31, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.13, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.21, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.27, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.21, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.27, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.22, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.38, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.38, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.37, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.22, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.22, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.41, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.41, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.03, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.51, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.41, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.41, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.28, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.62, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.44, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.45, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.56, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.42, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.42, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.5, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.68, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.03, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.4, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.4, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.15, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.51, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.62, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.44, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.44, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.29, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.57, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.71, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.33, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.33, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.4, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.62, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.74, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.08, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.55, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.55, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1906.14, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1905.21, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.66, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.63, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.73, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.41, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.41, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1907.1, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1906.27, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1905.13, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1903.37, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.45, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.6, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.53, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.55, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.55, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1905.37, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.52, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.55, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.68, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.43, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.43, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1904.71, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1904.2, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1903.36, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.73, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.41, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.62, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.57, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.57, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1903.2, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.36, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.6, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.59, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.54, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.54, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1905.03, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.17, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.14, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.46, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.54, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.54, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1904.47, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1903.04, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.25, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.2, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.17, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.66, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.66, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1904.42, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.21, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.26, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.43, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.43, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1904.48, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.29, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.45, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.45, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1906.34, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1905.23, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1904.15, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.39, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.35, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.35, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1904.11, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.07, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.31, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.23, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.55, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.55, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1905.18, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1904.43, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1903.51, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.11, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.53, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.1, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.43, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.43, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1906.24, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1905.46, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1905.09, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1904.69, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1904.29, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1903.74, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1903.18, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1902.42, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1901.36, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.45, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.44214e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.44214e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.31, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1904.67, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1904.67, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1904.67, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1904.67, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1904.67, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.44214e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1900 and h = 8.44214e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.31, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1904.67, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1904.67, mxstep steps taken before reaching tout.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   Internal t = 1904.67 and h = 8.5103e-14 are such that t + h = t on the next step. The solver will continue anyway.
#
#
# [CVODES WARNING]  CVode
#   The above warning has been issued mxhnil times and will not be issued again for this problem.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1904.67, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1904.67, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1904.67, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.97, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.97, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1906.02, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1909.09, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1910.05, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1911.29, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1912.37, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1910.07, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1912.97, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1912.97, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1911.15, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1914.49, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1914.04, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1913.51, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1916.63, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1916.63, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1915.53, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1918.87, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1918.87, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1918.5, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1918.18, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1917.66, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1919.69, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1919.39, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.09, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.14, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.08, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.14, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.28, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.29, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.27, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.37, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.45, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1909.09, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1911.98, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1911.98, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1911.24, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1910.09, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1913.92, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1913.92, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1913.31, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1912.45, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1915.83, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1915.83, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1915.34, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1914.65, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1917.6, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1917.6, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1917.07, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1916.63, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1916.15, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.11, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODES ERROR]  CVode
#   At t = 1908.04, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.87, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.87, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.09, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeF
#   At t = 1900.09, mxstep steps taken before reaching tout.
#
#
# [CVODES ERROR]  CVode
#   At t = 1900.01, mxstep steps taken before reaching tout.
#
#
# [CVODEA ERROR]  CVodeB
#   Error occured while integrating backward problem # 0
#
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 153 seconds.

# %%
from pymc3 import summary
summary(trace)
# Out:
# /opt/conda/lib/python3.9/site-packages/arviz/data/io_pymc3.py:96: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
#                    mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# log_speed_ratio  -0.084  0.078  -0.224    0.065      0.001    0.001    3096.0
# hares_start       3.505  0.109   3.294    3.704      0.002    0.002    2085.0
# lynx_start        1.886  0.078   1.734    2.029      0.001    0.001    2982.0
# ratio             0.820  0.023   0.775    0.862      0.000    0.000    2263.0
# fixed_hares       3.336  0.058   3.230    3.442      0.001    0.001    2735.0
# fixed_lynx        2.733  0.059   2.628    2.849      0.001    0.001    3009.0
# period           10.110  0.165   9.790   10.409      0.003    0.002    2409.0
# freq              0.622  0.010   0.603    0.641      0.000    0.000    2409.0
# alpha             0.470  0.041   0.387    0.544      0.001    0.001    2583.0
# beta              0.172  0.014   0.145    0.199      0.000    0.000    2808.0
# gamma             0.828  0.069   0.692    0.950      0.001    0.001    2922.0
# delta             0.248  0.020   0.212    0.286      0.000    0.000    2961.0
# hares_mu[0]       3.505  0.109   3.294    3.704      0.002    0.002    2085.0
# hares_mu[1]       3.996  0.102   3.809    4.187      0.002    0.001    2331.0
# hares_mu[2]       4.297  0.096   4.123    4.482      0.002    0.001    3101.0
# hares_mu[3]       4.172  0.104   3.973    4.359      0.002    0.001    3531.0
# hares_mu[4]       3.636  0.104   3.441    3.822      0.002    0.001    3608.0
# hares_mu[5]       3.028  0.090   2.851    3.185      0.001    0.001    4130.0
# hares_mu[6]       2.636  0.081   2.484    2.788      0.001    0.001    4045.0
# hares_mu[7]       2.518  0.079   2.365    2.662      0.001    0.001    3382.0
# hares_mu[8]       2.638  0.078   2.490    2.782      0.001    0.001    3030.0
# hares_mu[9]       2.951  0.076   2.817    3.107      0.001    0.001    2763.0
# hares_mu[10]      3.407  0.075   3.271    3.554      0.001    0.001    3050.0
# hares_mu[11]      3.910  0.083   3.748    4.056      0.001    0.001    3656.0
# hares_mu[12]      4.269  0.094   4.098    4.448      0.002    0.001    3434.0
# hares_mu[13]      4.236  0.098   4.062    4.432      0.002    0.001    3161.0
# hares_mu[14]      3.757  0.102   3.567    3.946      0.002    0.001    2750.0
# hares_mu[15]      3.134  0.100   2.935    3.307      0.002    0.001    2639.0
# hares_mu[16]      2.690  0.088   2.529    2.860      0.002    0.001    2754.0
# hares_mu[17]      2.523  0.079   2.364    2.659      0.001    0.001    3256.0
# hares_mu[18]      2.600  0.081   2.445    2.752      0.001    0.001    4051.0
# hares_mu[19]      2.880  0.094   2.713    3.068      0.001    0.001    4134.0
# hares_mu[20]      3.313  0.113   3.092    3.515      0.002    0.001    3982.0
# lynx_mu[0]        1.886  0.078   1.734    2.029      0.001    0.001    2982.0
# lynx_mu[1]        2.093  0.085   1.948    2.265      0.002    0.001    3139.0
# lynx_mu[2]        2.575  0.101   2.383    2.764      0.002    0.001    3089.0
# lynx_mu[3]        3.249  0.110   3.043    3.448      0.002    0.001    3412.0
# lynx_mu[4]        3.760  0.107   3.562    3.959      0.002    0.001    4028.0
# lynx_mu[5]        3.748  0.104   3.550    3.940      0.002    0.001    3651.0
# lynx_mu[6]        3.289  0.097   3.106    3.466      0.002    0.001    3044.0
# lynx_mu[7]        2.711  0.088   2.552    2.888      0.002    0.001    2840.0
# lynx_mu[8]        2.238  0.084   2.077    2.396      0.002    0.001    2842.0
# lynx_mu[9]        1.951  0.081   1.804    2.110      0.002    0.001    2890.0
# lynx_mu[10]       1.873  0.080   1.717    2.018      0.001    0.001    2931.0
# lynx_mu[11]       2.030  0.083   1.874    2.190      0.002    0.001    2986.0
# lynx_mu[12]       2.460  0.093   2.289    2.636      0.002    0.001    3118.0
# lynx_mu[13]       3.116  0.106   2.909    3.310      0.002    0.001    3376.0
# lynx_mu[14]       3.696  0.110   3.486    3.890      0.002    0.001    3782.0
# lynx_mu[15]       3.793  0.104   3.595    3.990      0.002    0.001    3893.0
# lynx_mu[16]       3.397  0.102   3.209    3.597      0.002    0.001    3870.0
# lynx_mu[17]       2.820  0.099   2.630    3.003      0.002    0.001    3758.0
# lynx_mu[18]       2.318  0.090   2.156    2.496      0.002    0.001    3508.0
# lynx_mu[19]       1.993  0.081   1.847    2.147      0.001    0.001    3214.0
# lynx_mu[20]       1.874  0.080   1.722    2.023      0.001    0.001    2911.0
# sd                0.262  0.032   0.206    0.322      0.001    0.000    2787.0
#
#                  ess_tail  r_hat
# log_speed_ratio    2635.0    1.0
# hares_start        2028.0    1.0
# lynx_start         2847.0    1.0
# ratio              2331.0    1.0
# fixed_hares        2766.0    1.0
# fixed_lynx         3019.0    1.0
# period             2580.0    1.0
# freq               2580.0    1.0
# alpha              2608.0    1.0
# beta               2707.0    1.0
# gamma              2594.0    1.0
# delta              2616.0    1.0
# hares_mu[0]        2028.0    1.0
# hares_mu[1]        2416.0    1.0
# hares_mu[2]        2734.0    1.0
# hares_mu[3]        3046.0    1.0
# hares_mu[4]        3013.0    1.0
# hares_mu[5]        3366.0    1.0
# hares_mu[6]        3095.0    1.0
# hares_mu[7]        2928.0    1.0
# hares_mu[8]        2723.0    1.0
# hares_mu[9]        2685.0    1.0
# hares_mu[10]       3065.0    1.0
# hares_mu[11]       3227.0    1.0
# hares_mu[12]       3144.0    1.0
# hares_mu[13]       3030.0    1.0
# hares_mu[14]       3232.0    1.0
# hares_mu[15]       2938.0    1.0
# hares_mu[16]       3008.0    1.0
# hares_mu[17]       2911.0    1.0
# hares_mu[18]       3284.0    1.0
# hares_mu[19]       3359.0    1.0
# hares_mu[20]       3411.0    1.0
# lynx_mu[0]         2847.0    1.0
# lynx_mu[1]         2862.0    1.0
# lynx_mu[2]         3014.0    1.0
# lynx_mu[3]         3228.0    1.0
# lynx_mu[4]         3350.0    1.0
# lynx_mu[5]         3644.0    1.0
# lynx_mu[6]         3265.0    1.0
# lynx_mu[7]         3014.0    1.0
# lynx_mu[8]         2649.0    1.0
# lynx_mu[9]         2746.0    1.0
# lynx_mu[10]        2640.0    1.0
# lynx_mu[11]        2820.0    1.0
# lynx_mu[12]        3272.0    1.0
# lynx_mu[13]        3353.0    1.0
# lynx_mu[14]        2968.0    1.0
# lynx_mu[15]        3739.0    1.0
# lynx_mu[16]        3703.0    1.0
# lynx_mu[17]        3269.0    1.0
# lynx_mu[18]        3056.0    1.0
# lynx_mu[19]        3129.0    1.0
# lynx_mu[20]        2553.0    1.0
# sd                 1825.0    1.0

# %%
from pymc3 import traceplot
traceplot(trace)
# Out:
# /tmp/ipykernel_17206/1367478007.py:2: DeprecationWarning: The function `traceplot` from PyMC3 is just an alias for `plot_trace` from ArviZ. Please switch to `pymc3.plot_trace` or `arviz.plot_trace`.
#   traceplot(trace)
# /opt/conda/lib/python3.9/site-packages/arviz/data/io_pymc3.py:96: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
# array([[<AxesSubplot:title={'center':'log_speed_ratio'}>,
#         <AxesSubplot:title={'center':'log_speed_ratio'}>],
#        [<AxesSubplot:title={'center':'hares_start'}>,
#         <AxesSubplot:title={'center':'hares_start'}>],
#        [<AxesSubplot:title={'center':'lynx_start'}>,
#         <AxesSubplot:title={'center':'lynx_start'}>],
#        [<AxesSubplot:title={'center':'ratio'}>,
#         <AxesSubplot:title={'center':'ratio'}>],
#        [<AxesSubplot:title={'center':'fixed_hares'}>,
#         <AxesSubplot:title={'center':'fixed_hares'}>],
#        [<AxesSubplot:title={'center':'fixed_lynx'}>,
#         <AxesSubplot:title={'center':'fixed_lynx'}>],
#        [<AxesSubplot:title={'center':'period'}>,
#         <AxesSubplot:title={'center':'period'}>],
#        [<AxesSubplot:title={'center':'freq'}>,
#         <AxesSubplot:title={'center':'freq'}>],
#        [<AxesSubplot:title={'center':'alpha'}>,
#         <AxesSubplot:title={'center':'alpha'}>],
#        [<AxesSubplot:title={'center':'beta'}>,
#         <AxesSubplot:title={'center':'beta'}>],
#        [<AxesSubplot:title={'center':'gamma'}>,
#         <AxesSubplot:title={'center':'gamma'}>],
#        [<AxesSubplot:title={'center':'delta'}>,
#         <AxesSubplot:title={'center':'delta'}>],
#        [<AxesSubplot:title={'center':'hares_mu'}>,
#         <AxesSubplot:title={'center':'hares_mu'}>],
#        [<AxesSubplot:title={'center':'lynx_mu'}>,
#         <AxesSubplot:title={'center':'lynx_mu'}>],
#        [<AxesSubplot:title={'center':'sd'}>,
#         <AxesSubplot:title={'center':'sd'}>]], dtype=object)
